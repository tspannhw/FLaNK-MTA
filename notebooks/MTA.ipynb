# %%
import pandas

# %%
df = pandas.read_json('http://localhost:18131/api/v1/query/5204/mta?key=2730dfe0-1e2d-4f74-866a-52f372531d60')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   VehicleRef                  333 non-null    object
#  1   StopPointName               333 non-null    object
#  2   Bearing                     333 non-null    float64
#  3   DestinationName             333 non-null    object
#  4   ExpectedArrivalTime         333 non-null    object
#  5   VehicleLocationLatitude     333 non-null    float64
#  6   VehicleLocationLongitude    333 non-null    float64
#  7   ArrivalProximityText        333 non-null    object
#  8   DistanceFromStop            333 non-null    int64
#  9   AimedArrivalTime            333 non-null    object
#  10  Date                        333 non-null    datetime64[ns, UTC]
#  11  ts                          333 non-null    int64
#  12  uuid                        333 non-null    object
#  13  EstimatedPassengerCapacity  333 non-null    object
#  14  EstimatedPassengerCount     333 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(3), int64(2), object(9)
# memory usage: 39.1+ KB

# %%
df
# Out:
#         VehicleRef                     StopPointName     Bearing  \
# 0    MTA NYCT_1240               WEBSTER AV/E 182 ST   57.128387
# 1    MTA NYCT_1266           W MOSHOLU PKY S/PAUL AV  300.963750
# 2    MTA NYCT_1276  CASTLE HILL AV/CROSS BX SVC RD N  282.871200
# 3    MTA NYCT_1255            W FORDHAM RD/JEROME AV    2.290610
# 4    MTA NYCT_1265        WESTCHESTER AV/BRUCKNER BL   68.552260
# ..             ...                               ...         ...
# 328     MTABC_4078               FOREST AV/HARMAN ST  177.249910
# 329     MTABC_5398                 PARSONS BL /88 AV   18.004162
# 330     MTABC_5393            CENTRAL AV/VIRGINIA ST  204.085280
# 331     MTABC_5392            SHERIDAN BL /CARVEL PL  258.111330
# 332     MTABC_4060                    HAZEN ST/19 AV  326.309940
#
#                                        DestinationName  \
# 0                WILLAMSBRIDGE GUN HILL RD via WEBSTER
# 1                      MOTT HAVEN 138 ST via CONCOURSE
# 2                                CASTLE HILL ZEREGA AV
# 3              BAY PLAZA via FORDHAM RD via PELHAM PKY
# 4              PELHAM BAY via STORY AV via BRUCKNER BL
# ..                                                 ...
# 328                                RIDGEWOOD COOPER AV
# 329             JAMAICA PARSONS-HILLSIDE via BREWER BL
# 330  LIMITED FAR ROCKAWAY SEAGIRT BL via BREWER BL/...
# 331      LIMITED FAR ROCKAWAY SEAGIRT BL via BREWER BL
# 332                     STEINWAY 19 AV via STEINWAY ST
#
#                ExpectedArrivalTime  VehicleLocationLatitude  \
# 0    2023-05-10T22:02:47.672-04:00                40.851581
# 1    2023-05-10T22:01:07.947-04:00                40.880737
# 2    2023-05-10T22:01:57.408-04:00                40.831389
# 3                                                 40.862777
# 4    2023-05-10T22:01:22.781-04:00                40.852985
# ..                             ...                      ...
# 328  2023-05-10T22:01:31.617-04:00                40.712919
# 329  2023-05-10T22:04:00.000-04:00                40.707528
# 330  2023-05-10T22:01:06.427-04:00                40.610397
# 331  2023-05-10T22:01:30.341-04:00                40.613569
# 332  2023-05-10T22:01:18.802-04:00                40.774116
#
#      VehicleLocationLongitude ArrivalProximityText  DistanceFromStop  \
# 0                  -73.898567        < 1 stop away               454
# 1                  -73.886076              at stop                13
# 2                  -73.850922        < 1 stop away               160
# 3                  -73.901595              at stop                18
# 4                  -73.826099          approaching               123
# ..                        ...                  ...               ...
# 328                -73.905746          approaching                74
# 329                -73.803337          approaching               101
# 330                -73.744020        < 1 stop away               154
# 331                -73.752875        < 1 stop away               155
# 332                -73.893493          approaching               105
#
#                   AimedArrivalTime                      Date             ts  \
# 0    2023-05-10T21:50:27.948-04:00 2023-05-11 02:01:09+00:00  1683770470641
# 1    2023-05-10T21:57:17.955-04:00 2023-05-11 02:01:09+00:00  1683770470641
# 2    2023-05-10T22:03:40.961-04:00 2023-05-11 02:01:09+00:00  1683770470641
# 3    2023-05-10T21:54:05.976-04:00 2023-05-11 02:01:09+00:00  1683770470641
# 4    2023-05-10T21:56:00.980-04:00 2023-05-11 02:01:09+00:00  1683770470642
# ..                             ...                       ...            ...
# 328  2023-05-10T21:48:50.637-04:00 2023-05-11 02:01:09+00:00  1683770470691
# 329  2023-05-10T22:04:00.642-04:00 2023-05-11 02:01:09+00:00  1683770470692
# 330  2023-05-10T22:02:47.646-04:00 2023-05-11 02:01:09+00:00  1683770470692
# 331  2023-05-10T21:56:41.650-04:00 2023-05-11 02:01:09+00:00  1683770470692
# 332  2023-05-10T21:06:00.654-04:00 2023-05-11 02:01:09+00:00  1683770470692
#
#                                      uuid EstimatedPassengerCapacity  \
# 0    23d6d29d-0cd7-45b8-a24e-0c1acd076578
# 1    64c1ccd7-fcd1-43a3-a89b-62fbbfb449ad
# 2    37b26b09-d44f-4c39-ad00-9278410dd6b9
# 3    c8d46059-a75b-463d-8230-b354a13ca846
# 4    d303eaaf-05f1-4618-b9be-81a6baccabfc
# ..                                    ...                        ...
# 328  dc97bec2-9954-49c0-8dc4-4dfe289bf76a                          0
# 329  24d09028-2b70-48a3-8348-dbbdf1275120                          0
# 330  80cf489f-3ef7-4895-aedb-41c42c8bc6ca                          0
# 331  28f3adc1-30d4-481e-bc60-f7ac3d506409                          0
# 332  21656c4c-47a8-4a53-abe4-8ac6d4e9ad11
#
#     EstimatedPassengerCount
# 0
# 1
# 2
# 3
# 4
# ..                      ...
# 328                       9
# 329                       7
# 330                      13
# 331                      24
# 332
#
# [333 rows x 15 columns]
